# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(x,y)
plt.plot(x,y, 'bo')
plt.plot(y)
plt.plot(y,'r+')

# %%
plt.title("plot")
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title("x ticks")
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %% [markdown]
# ## title() 한글 폰트가 깨진다

# %%
plt.title("한글 제목")
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %% [markdown]
# ## 한글 폰트 사용법

# %%
# 시스템 폰트 경로 리스트
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# Out:
# ['C:\\Windows\\Fonts\\H2GTRE.TTF', 'C:\\Windows\\Fonts\\OUTLOOK.TTF', 'C:\\WINDOWS\\Fonts\\calibri.ttf', 'C:\\WINDOWS\\Fonts\\seguisb.ttf', 'C:\\Windows\\Fonts\\NIAGSOL.TTF', 'C:\\Windows\\Fonts\\YuGothM.ttc', 'C:\\Windows\\Fonts\\BRITANIC.TTF', 'C:\\WINDOWS\\Fonts\\NGULIM.TTF', 'C:\\Windows\\Fonts\\ANTQUABI.TTF', 'C:\\Windows\\Fonts\\LeelUIsl.ttf', 'C:\\Windows\\Fonts\\ERASBD.TTF', 'C:\\WINDOWS\\Fonts\\GOTHICI.TTF', 'C:\\Windows\\Fonts\\DUBAI-REGULAR.TTF', 'C:\\Windows\\Fonts\\BOD_BLAI.TTF', 'C:\\WINDOWS\\Fonts\\comici.ttf', 'C:\\Windows\\Fonts\\pala.ttf', 'C:\\Windows\\Fonts\\HANBatangExtBB.ttf', 'C:\\WINDOWS\\Fonts\\ARIALNB.TTF', 'C:\\WINDOWS\\Fonts\\javatext.ttf', 'C:\\WINDOWS\\Fonts\\consola.ttf', 'C:\\WINDOWS\\Fonts\\GILC____.TTF', 'C:\\Windows\\Fonts\\LHANDW.TTF', 'C:\\WINDOWS\\Fonts\\TCBI____.TTF', 'C:\\WINDOWS\\Fonts\\phagspab.ttf', 'C:\\Windows\\Fonts\\GOTHIC.TTF', 'C:\\WINDOWS\\Fonts\\CENSCBK.TTF', 'C:\\Windows\\Fonts\\PERTILI.TTF', 'C:\\Windows\\Fonts\\mingliub.ttc', 'C:\
# ...

# %%
# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname='원하는 폰트 경로')
plt.rcParams['font.family'] = prop.get_family()

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumSquare Neo OTF Bold
# NanumSquare_ac
# D2Coding ligature
# NanumSquareRound
# NanumSquare Neo Bold
# NanumBarunGothicOTF
# NanumSquareOTF_ac
# NanumMyeongjo Eco
# Noto Sans KR
# NanumSquareOTF_ac
# NanumMyeongjoOTF
# NanumSquare Neo Regular
# NanumGothic
# NanumMyeongjo
# NanumSquare Neo OTF Regular
# NanumGothicOTF
# NanumMyeongjoOTF
# Noto Sans KR
# NanumMyeongjo Eco
# NanumBarunGothicOTF
# NanumGothic
# NanumSquare_ac
# NanumSquareOTF
# NanumSquareOTF_ac
# NanumSquare_ac
# NanumSquare Neo OTF ExtraBold
# Noto Sans KR
# NanumGothicOTF
# NanumGothicOTF Eco
# D2Coding ligature
# NanumMyeongjo
# NanumSquare Neo ExtraBold
# NanumMyeongjo Eco
# NanumSquareOTF_ac
# NanumSquare
# NanumBarunGothic YetHangul
# NanumGothic
# NanumGothic Eco
# NanumMyeongjoOTF YetHangul
# NanumSquareRound
# NanumSquareRound
# NanumSquareOTF
# NanumSquare_ac
# Nanum Pen Script
# NanumSquare
# NanumGothic Eco
# NanumGothic Eco
# NanumBarunpen
# NanumSquare
# NanumBarunGothicOTF
# D2Coding
# ...

# %%
plt.title("한글 제목")
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %%
global_font={'family' : 'NanumGothic','size' : 12 , 'weight' : 'bold'}

#폰트설정
mpl.rc('font', **global_font)

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40],[1,4,9,16])
plt.xlabel("엑스축 레이블")
plt.ylabel("와이축 레이블")
plt.show()

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])

# %%
title_font = {'family' : 'NanumMyeongjo',
              'size':24,
              'color':'black'}
xlabel_font = {'family': 'NanumBarunpen',
               'size':18,
               'weight' : 'bold',
               'color':'darkred'}
ylabel_font = { 'family':'NanumBarunGothic',
               'size':12,
               'weight':'light',
               'color':'blue'}

plt.plot([10,20,30,40],[1,4,9,16])
plt.title('한글 제목', fontdict = title_font)
plt.xlabel('엑스 축',fontdict = xlabel_font)
plt.ylabel('와이 축', fontdict = ylabel_font)
plt.show()

# %%
# unicode minus : -1
# ASCII hyphen : -1

# %%
# 유니코드에서 음수 부호 설정
mpl.rc('axes', unicode_minus=False)

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['fonts/nanum-all']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumSquare Neo OTF Bold
# NanumSquare_ac
# D2Coding ligature
# NanumSquareRound
# NanumSquare Neo Bold
# NanumBarunGothicOTF
# NanumSquareOTF_ac
# NanumMyeongjo Eco
# NanumSquareOTF_ac
# NanumMyeongjoOTF
# NanumSquare Neo Regular
# NanumGothic
# NanumMyeongjo
# NanumSquare Neo OTF Regular
# NanumGothicOTF
# NanumMyeongjoOTF
# NanumMyeongjo Eco
# NanumBarunGothicOTF
# NanumGothic
# NanumSquare_ac
# NanumSquareOTF
# NanumSquareOTF_ac
# NanumSquare_ac
# NanumSquare Neo OTF ExtraBold
# NanumGothicOTF
# NanumGothicOTF Eco
# D2Coding ligature
# NanumMyeongjo
# NanumSquare Neo ExtraBold
# NanumMyeongjo Eco
# NanumSquareOTF_ac
# NanumSquare
# NanumBarunGothic YetHangul
# NanumGothic
# NanumGothic Eco
# NanumMyeongjoOTF YetHangul
# NanumSquareRound
# NanumSquareRound
# NanumSquareOTF
# NanumSquare_ac
# Nanum Pen Script
# NanumSquare
# NanumGothic Eco
# NanumGothic Eco
# NanumBarunpen
# NanumSquare
# NanumBarunGothicOTF
# D2Coding
# NanumBarunGothicOTF
# NanumMyeongjoOTF Eco
# ...

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'NanumSquare Neo OTF Bold'
print(mpl.rcParams['font.family'])
# Out:
# ['NanumSquare Neo OTF Bold']

# %%
plt.title("defalt 스타일의 plot")
plt.plot([10,20,30,40],[1,4,9,16])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.title("'rs--' 스타일의 plot")
plt.plot([10,20,30,40],[1,4,9,16], 'rp--')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot([10,20,30,40],[1,4,9,16],c="b",
         lw=3, ls="--", marker="o", ms=10, mew=5,mfc="k")
plt.title("스타일 적용 예")
plt.show()

# %% [markdown]
# ### xlim , ylim 으로 축의 최소 최대 범위를 설정

# %%
plt.title("x축 , y축의 범위 설정")
plt.plot([10,20,30,40],[1,4,9,16],c="b",
         lw=3, ls="--", marker="o", ms=10, mec="g",mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %%
# 틱 설정하기

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("X축과 Y축의 tick label 설정")
plt.plot(X,C)
plt.xticks([np.pi , -np.pi / 2,0,np.pi / 2,np.pi])
plt.yticks([-1,0,+1])
plt.show()

# %%
#틱 위치나 라벨은 맷플롯리브가 자동으로 정해주지만  
#수동으로 설정하고 싶다면 xticks()나 yticks()사용

# %%
# 틱 라벨 문자열에는 $$사이에 수학 문자식을 넣을수있다.

# %%
X = np.linspace(-np.pi, np.pi,256)
C = np.cos(X)
plt.title(" Tex, 문자열로 tick lavel 정의")
plt.plot(X,C)
plt.xticks([-np.pi , -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1,0,1],["Low","Zero","High"])
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %%
plt.title("복수의 plot명령을 한 그림에서 표현")
style1 = {"c" : "b",  "lw" : 5, "ls" : "--" , "marker" : "o" , "ms": 15, "mec":"g", "mew":5, "mfc":"r"}
style2 = {"c" : "k",  "lw" : 3, "ls" : ":" , "marker" : "s" , "ms": 10, "mec":"m", "mew":5, "mfc":"c"}

plt.plot([1,4,9,16], **style1)
plt.plot([9,16,4,1], **style2)

plt.show()

# %% [markdown]
# # 범례

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X,C, ls="--", label = "cosine")
plt.plot(X,S, ls=":", label = "sine")
plt.legend(loc=2)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X,C, label = "cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %%
x = np.arange(32,100)
y = (x-32)*5/9

plt.plot(x,y,"r-.")
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")
plt.title("섭씨 온도와 화씨 온도")
plt.show()

# %%
fig, ax = plt.subplots() #Create a figure containing asingle axes.
ax.plot([1,2,3,4],[1,4,2,3]); # Plot some data on the axes.

# %%
fig = plt.figure()
fig, ax = plt.subplots()
fig, axs = plt.subplots(2,2)

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10,2))
plt.title("figure size : (10,2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
plt.title("현재의 Figure 객체")
plt.plot([1,2,3,4],'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 2590723757152
# Figure(640x480) 2590723757152

# %%
ax1 = plt.subplot(2,1,1)
ax2 = plt.subplot(2,1,2)

# %% [markdown]
# ## tight_layout() 명령을 실행하면 플롯 간의 간격을 자동으로 맞춰줌

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

# %%
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1,y1,'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel( 'Dampled oscillation')

ax2 = plt.subplot(2,1,2)
plt.plot(x2,y2,'r.-')
plt.xlabel('time (s) ')
plt.ylabel('Undamped')
plt.tight_layout()
plt.show()

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## twinx()를 사용해서 복수의 y축을 가진 플롯을 만듦

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10,5,2,9,7],'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100,200,220,180,120],'g:', label="y1")
ax1.set_ylabel("y1")
ax.grid(False)
ax0.set_xlabel("공유되는 x축")
plt.show()

# %%
y = [2,3,1]
x = ['가','나','다']
plt.title("Bar Chart")
plt.bar(x,y)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
y = [2,3,1]
x = ['가','나','다']
colors = ["red","green","blue"]

plt.title("Bar Chart")
plt.bar(x,y, color=colors)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %% [markdown]
# ## xerr/yerr인수로 에러바를 추가 할 수있다.

# %%
np.random.seed(0)

people = ['몽룡','춘향','방자','향단']
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(people, performance, xerr=error,alpha=0.4)
plt.xlabel('x라벨')
plt.show()

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic["alive"].value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
ti_chart = titanic["alive"].value_counts()
ti_chart.rename({'no':'사망자','yes':'생존자'}, inplace=True)
ti_chart
# Out:
# 사망자    549
# 생존자    342
# Name: alive, dtype: int64

# %%
ti_chart.index
# Out:
# Index(['사망자', '생존자'], dtype='object')

# %%
ti_chart.values
# Out:
# array([549, 342], dtype=int64)

# %%
plt.grid()
alive = ti_chart.index
value = ti_chart.values
plt.title("타이타닉호 생존 여부")
plt.barh(alive, value, color=["r","g"])
plt.xlabel('인원 수')
plt.show()

# %%
labels = ['월세','전세','자가','기타']
sizes = [15,30,45,10]
colors=['yellowgreen','gold','lightskyblue','lightcoral']
explode = (0,0,0.1,0) # 0.1만큼 튀어나오게 한다.
plt.title("Pie Cjart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
explode = (0.1, 0, 0, 0, 0)
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

# %%
import pandas as pd
titanic_age = pd.cut(titanic["age"],bins=bins, labels=labels).value_counts()

# %%
titanic_age.values
# Out:
# array([241, 230, 179,  59,   5], dtype=int64)

# %%
sizes = titanic_age
plt.title("titanic")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
한글키예영 ㅎㅎㅎㅎㅎㅎㅎ]
하하하하하하하하ㅏ이것도 이거 완전 좋다
이거 두드려보고 산거인가여?     ㅅ호리 대박신기방기다
와
너무 
신기하다
너무
좋다
와ㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏ

# %% [markdown]
# # 히스토그램을 그리기 위한 hist명령

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title("Histogram")
arrays, bins, patches = plt.hist(x, bins = 10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %% [markdown]
# ## 스캐터 플롯 2차원 데이터

# %%
np.random.seed(0)
X = np.random.normal(0,1,100)
Y = np.random.normal(0,1,100)
plt.title("Scatter Plot")
plt.scatter(X,Y)
plt.show()

# %%
N=30
np.random.seed(0)
x = np.random.rand(N)
y1=np.random.rand(N)
y2=np.random.rand(N)
y2=np.random.rand(N)
y3=np.pi*(15*np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x,y1,c=y2,s=y3)
plt.show()

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits; 0")
plt.imshow(X, interpolation='nearest', cmap = plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %% [markdown]
# ### 데이터 수치를 색으로 바꾸는 함수는 칼라맵이라고 한다.

# %%
dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots(1,4,figsize=(12,3),
                         subplot_kw = {'xticks':[],'yticks':[]})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(X, interpolation='nearest',cmap=plt.cm.Blues)
axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(X, interpolation='nearest',cmap=plt.cm.Blues_r)
axes[2].set_title("plt.BrBG")
axes[2].imshow(X, interpolation='nearest',cmap=plt.cm.BrBG)
axes[3].set_title("plt.BrBG_r")
axes[3].imshow(X, interpolation='nearest',cmap=plt.cm.BrBG_r)
plt.show()

# %%
methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()

# %%
def f(x,y):
    return (1-x/2+x**5+y**3) * np.exp(-x**2-y**2)

n=256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
XX,YY = np.meshgrid(x,y)
ZZ = f(XX,YY)

plt.title("Contour plots")
plt.contourf(XX,YY,ZZ ,alpha = .75, cmap='jet')
plt.contour(XX,YY,ZZ, colors = 'black')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4,4,0.25)
Y = np.arange(-4,4,0.25)
XX, YY = np.meshgrid(X,Y)
RR = np.sqrt(XX**2 +YY**2)
ZZ = np.sin(RR)
fig = plt.figure()
ax = Axes3D(fig)
ax.set_title('3D surface Plot')
ax.plot_surface(XX,YY,ZZ, rstride=1, cstride=1, cmap='hot')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23324\3956121169.py:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
