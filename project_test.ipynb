# %%
# Python3 샘플 코드 #

from bs4 import BeautifulSoup
import requests

url = 'http://apis.data.go.kr/B551172/thrd/patientNumber'
params ={'serviceKey' : 'R5ypB93DJ/ynR6onZknXJyjQSU498Oq7WSErqucTLk4dzSa350lKjtGnDLfkwL9caJnlbIVGmQ4jV4p1J0r2ig==', 'type' : 'xml, json', 'pageNo' : '1', 'numOfRows' : '100', 'centerNm' : '국립암센터', 'fromYear' : '2010', 'toYear' : '2019' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"count":0,"pageNo":1,"numOfRows":100,"totalCount":1095,"resultCode":200,"resultMsg":"NORMAL SERVICE","items":{"item":[{"statsMetaNo":12010,"centerNm":"\xea\xb5\xad\xeb\xa6\xbd\xec\x95\x94\xec\x84\xbc\xed\x84\xb0","critYr":2010,"ptAge":49,"ptSexCd":"F","statsTrgtNm":"","ncsNmvl":0,"wholNcsDnmvl":0,"ptCntNmvl":28,"wholPtCntDnmvl":0},{"statsMetaNo":12010,"centerNm":"\xea\xb5\xad\xeb\xa6\xbd\xec\x95\x94\xec\x84\xbc\xed\x84\xb0","critYr":2011,"ptAge":37,"ptSexCd":"F","statsTrgtNm":"","ncsNmvl":0,"wholNcsDnmvl":0,"ptCntNmvl":17,"wholPtCntDnmvl":0},{"statsMetaNo":12010,"centerNm":"\xea\xb5\xad\xeb\xa6\xbd\xec\x95\x94\xec\x84\xbc\xed\x84\xb0","critYr":2013,"ptAge":51,"ptSexCd":"M","statsTrgtNm":"","ncsNmvl":0,"wholNcsDnmvl":0,"ptCntNmvl":11,"wholPtCntDnmvl":0},{"statsMetaNo":12010,"centerNm":"\xea\xb5\xad\xeb\xa6\xbd\xec\x95\x94\xec\x84\xbc\xed\x84\xb0","critYr":2010,"ptAge":69,"ptSexCd":"F","statsTrgtNm":"","ncsNmvl":0,"wholNcsDnmvl":0,"ptCntNmvl":4,"wholPtCntDnmvl":0},{"stat
# ...

# %%
print(response.status_code)
# Out:
# 200

# %%
import json
import requests
import os
import pandas as pd
import time

#url = 'http://apis.data.go.kr/B551172/Pancreatic11/pnCaseByType'
#params ={'serviceKey' : 'NBsBEdkzbugNFtyl3fODWnDN/4+X1wcbKh6Hp6JSq9uOF7dmZm9dlVaMOKc7lFq5DV3MICzBM0fOr4hSl+BSjg==', 'type' : 'json', 'pageNo' : '1', 'numOfRows' : '100', 'centerNm' : '국립암센터', 'fromYear' : '2010', 'toYear' : '2019' }
cnt = 1;
response = None
while True:
    response = requests.get(url, params = params)
    #print(response.content)
    #response.status_code
    try:
        data = response.json()
        if data == None:
            break;
        else:
            a = pd.DataFrame(data['response']['items']['item'])
            if not os.path.exists('test1.csv'):
                a.to_csv('test1.csv', index=False, mode='w', encoding='utf-8-sig')
            else:
                a.to_csv('test1.csv', index=False, mode='a', encoding='utf-8-sig', header=False)
    except:
        break
    cnt += 1
    time.sleep(2)
#data2 = pd.read_csv("test1.csv",encoding="CP949")
#data2

# %%
response.status_code
# Out:
# 200

# %%
"""response = requests.get('http://apis.data.go.kr/B551172/thrd', 
                    params = {'serviceKey' : 'R5ypB93DJ%2FynR6onZknXJyjQSU498Oq7WSErqucTLk4dzSa350lKjtGnDLfkwL9caJnlbIVGmQ4jV4p1J0r2ig%3D%3D', 'type' : 'json', 'pageNo' : '1', 'numOfRows' : '100', 'centerNm' : '국립암센터', 'fromYear' : '2010', 'toYear' : '2019' }
)"""
# Out:
# "response = requests.get('http://apis.data.go.kr/B551172/thrd', \n                    params = {'serviceKey' : 'R5ypB93DJ%2FynR6onZknXJyjQSU498Oq7WSErqucTLk4dzSa350lKjtGnDLfkwL9caJnlbIVGmQ4jV4p1J0r2ig%3D%3D', 'type' : 'json', 'pageNo' : '1', 'numOfRows' : '100', 'centerNm' : '국립암센터', 'fromYear' : '2010', 'toYear' : '2019' }\n)"

# %%
response.json()
# Out:
# {'response': {'count': 0,
#   'pageNo': 1,
#   'numOfRows': 100,
#   'totalCount': 1095,
#   'resultCode': 200,
#   'resultMsg': 'NORMAL SERVICE',
#   'items': {'item': [{'statsMetaNo': 12010,
#      'centerNm': '국립암센터',
#      'critYr': 2010,
#      'ptAge': 49,
#      'ptSexCd': 'F',
#      'statsTrgtNm': '',
#      'ncsNmvl': 0,
#      'wholNcsDnmvl': 0,
#      'ptCntNmvl': 28,
#      'wholPtCntDnmvl': 0},
#     {'statsMetaNo': 12010,
#      'centerNm': '국립암센터',
#      'critYr': 2011,
#      'ptAge': 37,
#      'ptSexCd': 'F',
#      'statsTrgtNm': '',
#      'ncsNmvl': 0,
#      'wholNcsDnmvl': 0,
#      'ptCntNmvl': 17,
#      'wholPtCntDnmvl': 0},
#     {'statsMetaNo': 12010,
#      'centerNm': '국립암센터',
#      'critYr': 2013,
#      'ptAge': 51,
#      'ptSexCd': 'M',
#      'statsTrgtNm': '',
#      'ncsNmvl': 0,
#      'wholNcsDnmvl': 0,
#      'ptCntNmvl': 11,
#      'wholPtCntDnmvl': 0},
#     {'statsMetaNo': 12010,
#      'centerNm': '국립암센터',
#      'critYr': 2010,
# ...

# %%
data = response.json()['response']['items']['item']

# %%
pd.DataFrame(data)
# Out:
#     statsMetaNo centerNm  critYr  ptAge ptSexCd statsTrgtNm  ncsNmvl  \
# 0         12010    국립암센터    2010     49       F                    0
# 1         12010    국립암센터    2011     37       F                    0
# 2         12010    국립암센터    2013     51       M                    0
# 3         12010    국립암센터    2010     69       F                    0
# 4         12010    국립암센터    2013     53       F                    0
# ..          ...      ...     ...    ...     ...         ...      ...
# 95        12010    국립암센터    2014     72       F                    0
# 96        12010    국립암센터    2018     41       F                    0
# 97        12010    국립암센터    2019     51       M                    0
# 98        12010    국립암센터    2015     89       M                    0
# 99        12010    국립암센터    2011     61       F                    0
#
#     wholNcsDnmvl  ptCntNmvl  wholPtCntDnmvl
# 0              0         28               0
# 1              0         17               0
# ...

# %%
data_am = pd.DataFrame(data)

# %%
import pandas as pd
file = pd.read_csv("datas/경찰청_범죄 발생 장소별 통계_20211231.csv", encoding="cp949")
file
# Out:
#      범죄대분류        범죄중분류  아파트_연립다세대   단독주택  고속도로      노상   백화점  슈퍼마켓   편의점  \
# 0     강력범죄         살인기수         92     57     1      43     0     0     0
# 1     강력범죄        살인미수등        116     67     1      87     0     3     3
# 2     강력범죄           강도         78     47     1     114     2    10    39
# 3     강력범죄           강간       1561    976     2     127     0     0     1
# 4     강력범죄         유사강간        247    147     0      36     0     0     2
# 5     강력범죄         강제추행       1761   1096    16    2602    21   117   226
# 6     강력범죄  기타 강간_강제추행등         78     71     0       8     0     1     1
# 7     강력범죄           방화        279    246     0     153     0     1     1
# 8     절도범죄         절도범죄      16482   8535    99   46374  2142  9920  6143
# 9     폭력범죄           상해       4876   3014    50    9761    18    90   157
# 10    폭력범죄           폭행      23656  12716   206   41284    77   526  1365
# 11    폭력범죄        체포_감금        259    141     6     209     0     1     5
# ...
